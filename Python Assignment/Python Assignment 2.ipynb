# %%
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
for i in range(1, 3):
    for j in range(0, 5):
        if i == 1:
            print('*'*(i+j))
        else:
            print('*'*(4-j+1))
# Out:
# *
# **
# ***
# ****
# *****
# *****
# ****
# ***
# **
# *

# %%
# take string as user input
# print the string in reverse

# %%
user_input = input('Print a string: ')
print('String in reverse order: {}'.format(user_input[::-1]))
# Out:
# Print a string: Malayalam
# String in reverse order: malayalaM
