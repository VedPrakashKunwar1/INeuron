# %% [markdown]
# ### Load library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from sklearn import datasets

# %matplotlib inline

# %%
datasets.load_iris().keys()[]
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %% [markdown]
# ### Create dataset

# %%
# create data frame
df = pd.DataFrame(data=datasets.load_iris()['data'], columns=datasets.load_iris()['feature_names'])
df.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['Species'] = datasets.load_iris()['target']
df.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  Species
# 0                5.1               3.5  ...               0.2        0
# 1                4.9               3.0  ...               0.2        0
# 2                4.7               3.2  ...               0.2        0
# 3                4.6               3.1  ...               0.2        0
# 4                5.0               3.6  ...               0.2        0
#
# [5 rows x 5 columns]

# %%
species_map = {i:k for i, k in enumerate(species)}
df['Species_label'] = df['Species'].map(species_map)
df.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  ...  Species  Species_label
# 0                5.1               3.5  ...        0         setosa
# 1                4.9               3.0  ...        0         setosa
# 2                4.7               3.2  ...        0         setosa
# 3                4.6               3.1  ...        0         setosa
# 4                5.0               3.6  ...        0         setosa
#
# [5 rows x 6 columns]

# %% [markdown]
# ### Create 3d plot

# %%
df.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  ...  Species  Species_label
# 0                5.1               3.5  ...        0         setosa
# 1                4.9               3.0  ...        0         setosa
# 2                4.7               3.2  ...        0         setosa
# 3                4.6               3.1  ...        0         setosa
# 4                5.0               3.6  ...        0         setosa
#
# [5 rows x 6 columns]

# %%
species_map
# Out:
# {0: 'setosa', 1: 'versicolor', 2: 'virginica'}

# %%
df0 = df.loc[df['Species']==0, :]
df1 = df.loc[df['Species']==1, :]
df2 = df.loc[df['Species']==2, :]

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')

ax.scatter(xs=df0['sepal length (cm)'], 
           ys=df0['sepal width (cm)'], 
           zs=df0['petal length (cm)'],
           s=df0['petal width (cm)']*100,
           c='blue',
           alpha=0.5,
           label='setosa'          
)
ax.scatter(xs=df1['sepal length (cm)'], 
           ys=df1['sepal width (cm)'], 
           zs=df1['petal length (cm)'],
           s=df1['petal width (cm)']*100,
           c='#FF69B4',
           alpha=0.5,
           label='versicolor'          
)
ax.scatter(xs=df2['sepal length (cm)'], 
           ys=df2['sepal width (cm)'], 
           zs=df2['petal length (cm)'],
           s=df2['petal width (cm)']*100,
           c='#8FBC8F',
           alpha=0.5,
           label='virginica'          
)
ax.set_xlabel('sepal length')
ax.set_ylabel('sepal width')
ax.set_zlabel('petal length')
plt.legend()
