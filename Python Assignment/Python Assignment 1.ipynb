# %%
# number between 2000 & 3000 (both incl.)
# divisible by 7
# not divisible by 5
# print in same line

# %%
for i in range(2000, 3001):
    if i % 7 == 0:
        if i % 5 != 0:
            print(i),

# %%
# user input first name and last name
# print name in reverse order

# %%
fname = input('please enter first name:  ')
lname = input('please enter last name:  ')

print('Name: {} {}'.format(lname, fname))
# Out:
# please enter first name:  Kane
# please enter last name:  Williamson
# Name: Williamson Kane

# %%
# volumn of sphere

# %%
import math
def sphereVolume(diameter):
    radius = diameter/2.0
    return (4/3)*(math.pi)*(radius**3)

print(sphereVolume(12))
# Out:
# 904.7786842338603
